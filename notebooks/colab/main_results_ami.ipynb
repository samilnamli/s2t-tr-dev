# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyin-karaca/s2t-tr-dev/blob/main_v2/notebooks/colab/main_results_ami.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
os.environ['GITHUB_TOKEN'] = userdata.get('GitHubPAT')
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
os.environ['DAGSHUB_USER_TOKEN'] = userdata.get('DAGSHUB_USER_TOKEN')


os.environ['DAGSHUB_TRACKING_URI']="https://dagshub.com/huseyin-karaca/s2t-tr-dev.mlflow"
os.environ['DAGSHUB_USERNAME']="huseyin-karaca"

os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')

# !gh auth status
# !git config --global user.name 'huseyin-karaca'
# !git config --global user.email 'huseyinkaraccca@gmail.com'
# Out:
# github.com
#   ✓ Logged in to github.com account huseyin-karaca (GITHUB_TOKEN)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AUNXCOA01Derj8bnLEVE_***********************************************************

# %%
# !uv run make run CONFIG=main_results_ami
# Out:
# 2026-05-06 06:28:59.288 | INFO     | __main__:fetch:52 - Downloading processed AMI dataset to data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet...
# Downloading...
# From (original): https://drive.google.com/uc?id=1FgN4FQ422HPDCwG-Wl4jrXQGl0tgX6ZP
# From (redirected): https://drive.google.com/uc?id=1FgN4FQ422HPDCwG-Wl4jrXQGl0tgX6ZP&confirm=t&uuid=7d30a9ab-0551-428c-9864-d8660bfffd4f
# To: /content/s2t-tr-dev/data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet
# 100% 7.96G/7.96G [01:40<00:00, 79.2MB/s]
# 2026-05-06 06:30:42.010 | INFO     | __main__:fetch:58 - Download completed successfully: data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet

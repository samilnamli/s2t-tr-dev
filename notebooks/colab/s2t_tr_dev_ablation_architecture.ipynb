# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyin-karaca/s2t-tr-dev/blob/main/notebooks/colab/s2t_tr_dev_ablation_architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Architecture Ablation (AMI)
#
# Reproduces the architecture-ablation table in Section 4.3 of the manuscript. Each variant changes one knob from the default hierarchical-transformer config; all variants share the same loss config (the best one from the loss ablation: `λ_wer=1.0, λ_hard=0.0, λ_soft=0.5, τ=0.1`).
#
# The full sweep runs **8 variants** end-to-end; expect ~3–4 hours on L4 with 50 epochs each. To do a quick smoke test first, run a single variant with `--max-epochs 2` (see below).

# %% [markdown]
# ## 1. Initial setup (clone + uv env + secrets)
#
# GPU recommendation:
# - **L4** (default): best price/performance for these notebooks. ~1.5–3× faster than T4 with no per-second penalty.
# - **A100**: ~2× faster than L4, ~2× the price. Use only if you want the full 50-epoch run in under 30 minutes.
# - **T4**: works but slow; halve `batch_size` if you OOM.

# %%
! git clone https://github.com/huseyin-karaca/s2t-tr-dev
# %cd /content/s2t-tr-dev

from google.colab import files
files.view('/content/s2t-tr-dev')

# !make create_environment
# !make requirements

from google.colab import userdata
import os
os.environ['GITHUB_TOKEN'] = userdata.get('GitHubPAT')
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# !gh auth status
# !git config --global user.name 'huseyin-karaca'
# !git config --global user.email 'huseyinkaraccca@gmail.com'

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 's2t-tr-dev'...
# remote: Enumerating objects: 368, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 368 (delta 57), reused 102 (delta 42), pack-reused 244 (from 2)
# Receiving objects: 100% (368/368), 738.73 MiB | 19.32 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# Updating files: 100% (148/148), done.
# /content/s2t-tr-dev
# uv venv --python 3.10
# warning: The `--system` flag has no effect, `uv venv` always ignores virtual environments when finding a Python interpreter; did you mean `--no-managed-python`?
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# >>> New uv virtual environment created. Activate with:
# >>> Windows: .\.venv\Scripts\activate
# >>> Unix/macOS: source ./.venv/bin/activate
# uv sync
# Resolved 199 packages in 11ms
# Prepared 195 packages in 41.61s
# Installed 195 packages in 322ms
#  + absl-py==2.4.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + anyio==4.13.0
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.3.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + audioread==3.1.0
#  + babel==2.18.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + certifi==2026.2.25
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + click==8.3.2
#  + comm==0.2.3
#  + contourpy==1.3.2
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.3
#  + cuda-toolkit==13.0.2
#  + cycler==0.12.1
#  + datasets==3.6.0
#  + debugpy==1.8.20
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + dill==0.3.8
#  + dotenv==0.9.9
#  + evaluate==0.4.6
#  + exceptiongroup==1.3.1
#  + executing==2.2.1
#  + fastjsonschema==2.21.2
#  + filelock==3.28.0
#  + fonttools==4.62.1
#  + fqdn==1.5.1
#  + frozenlist==1.8.0
#  + fsspec==2025.3.0
#  + ghp-import==2.1.0
#  + grpcio==1.80.0
#  + h11==0.16.0
#  + hf-xet==1.4.3
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.11.0
#  + idna==3.11
#  + ipykernel==7.2.0
#  + ipython==8.39.0
#  + isoduration==20.11.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiwer==4.0.0
#  + joblib==1.5.3
#  + json5==0.14.0
#  + jsonpointer==3.1.1
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + jupyter-client==8.8.0
#  + jupyter-core==5.9.1
#  + jupyter-events==0.12.0
#  + jupyter-lsp==2.3.1
#  + jupyter-server==2.17.0
#  + jupyter-server-terminals==0.5.4
#  + jupyterlab==4.5.6
#  + jupyterlab-pygments==0.3.0
#  + jupyterlab-server==2.28.0
#  + kiwisolver==1.5.0
#  + lark==1.3.1
#  + lazy-loader==0.5
#  + librosa==0.11.0
#  + lightning-utilities==0.15.3
#  + llvmlite==0.47.0
#  + loguru==0.7.3
#  + markdown==3.10.2
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mergedeep==1.3.4
#  + mistune==3.2.0
#  + mkdocs==1.6.1
#  + mkdocs-get-deps==0.2.2
#  + mpmath==1.3.0
#  + msgpack==1.1.2
#  + multidict==6.7.1
#  + multiprocess==0.70.16
#  + nbclient==0.10.4
#  + nbconvert==7.17.1
#  + nbformat==5.10.4
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + notebook==7.5.5
#  + notebook-shim==0.2.4
#  + numba==0.65.0
#  + numpy==2.2.6
#  + nvidia-cublas==13.1.0.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.19.0.56
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.0
#  + nvidia-nccl-cu13==2.28.9
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + overrides==7.7.0
#  + packaging==26.1
#  + pandas==2.3.3
#  + pandocfilters==1.5.1
#  + parso==0.8.6
#  + pathspec==1.0.4
#  + pexpect==4.9.0
#  + pillow==12.2.0
#  + pip==26.0.1
#  + platformdirs==4.9.6
#  + pooch==1.9.0
#  + prometheus-client==0.25.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==7.34.1
#  + psutil==7.2.2
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==23.0.1
#  + pycparser==3.0
#  + pygments==2.20.0
#  + pyparsing==3.3.2
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.2.2
#  + python-json-logger==4.1.0
#  + pytorch-lightning==2.6.1
#  + pytz==2026.1.post1
#  + pyyaml==6.0.3
#  + pyyaml-env-tag==1.1
#  + pyzmq==27.1.0
#  + rapidfuzz==3.14.5
#  + referencing==0.37.0
#  + regex==2026.4.4
#  + requests==2.33.1
#  + rfc3339-validator==0.1.4
#  + rfc3986-validator==0.1.1
#  + rfc3987-syntax==1.1.0
#  + rich==15.0.0
#  + rpds-py==0.30.0
#  + ruff==0.15.11
#  + safetensors==0.7.0
#  + scikit-learn==1.7.2
#  + scipy==1.15.3
#  + send2trash==2.1.0
#  + setuptools==81.0.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + soundfile==0.13.1
#  + soupsieve==2.8.3
#  + soxr==1.0.0
#  + src==0.0.1 (from file:///content/s2t-tr-dev)
#  + stack-data==0.6.3
#  + sympy==1.14.0
#  + tensorboard==2.20.0
#  + tensorboard-data-server==0.7.2
#  + terminado==0.18.1
#  + threadpoolctl==3.6.0
#  + tinycss2==1.4.0
#  + tokenizers==0.22.2
#  + tomli==2.4.1
#  + torch==2.11.0
#  + torchmetrics==1.9.0
#  + tornado==6.5.5
#  + tqdm==4.67.3
#  + traitlets==5.14.3
#  + transformers==5.5.4
#  + triton==3.6.0
#  + typer==0.24.1
#  + typing-extensions==4.15.0
#  + tzdata==2026.1
#  + uri-template==1.3.0
#  + urllib3==2.6.3
#  + watchdog==6.0.0
#  + wcwidth==0.6.0
#  + webcolors==25.10.0
#  + webencodings==0.5.1
#  + websocket-client==1.9.0
#  + werkzeug==3.1.8
#  + xxhash==3.6.0
#  + yarl==1.23.0
# github.com
#   ✓ Logged in to github.com account huseyin-karaca (GITHUB_TOKEN)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AUNXCOA01Derj8bnLEVE_***********************************************************
# Mounted at /content/drive

# %% [markdown]
# ## 2. Bring in the AMI interim features from Drive
#
# Reuses the per-expert interim parquets you have already generated and saved to Drive (no re-extraction). Then runs the patched preprocess script that propagates the `_transcription` columns alongside the embeddings/WERs.
#
# > **Adjust `DRIVE_INTERIM_AMI` below** to your actual Drive folder path before running.

# %%
# Path on Drive that contains the three per-expert interim parquets:
#   openai_whisper-base.parquet
#   facebook_hubert-large-ls960-ft.parquet
#   facebook_wav2vec2-base-960h.parquet
DRIVE_INTERIM_AMI = '/content/drive/MyDrive/s2t-tr-dev/data/interim/edinburghcstr_ami'

# !mkdir -p data/interim/edinburghcstr_ami
# !cp -v "$DRIVE_INTERIM_AMI"/*.parquet data/interim/edinburghcstr_ami/
# !ls -lh data/interim/edinburghcstr_ami/

# %%
# !uv run python -m src.data.preprocess \
    --dataset edinburghcstr/ami \
    --output_name combined_features_with_transcripts.parquet

# %%
DRIVE_PROCESSED_AMI = '/content/drive/My Drive/s2t-tr-dev/data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet'

# !mkdir -p data/processed/edinburghcstr_ami
# !cp -v "$DRIVE_PROCESSED_AMI" /content/s2t-tr-dev/data/processed/edinburghcstr_ami/
# !ls -lh data/processed/edinburghcstr_ami/
# Out:
# '/content/drive/My Drive/s2t-tr-dev/data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet' -> '/content/s2t-tr-dev/data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet'
# total 7.5G
# -rw------- 1 root root 7.5G Apr 26 19:47 combined_features-w2v2-large.parquet

# %% [markdown]
# ## 3. Smoke test (single variant, 2 epochs)
#
# Confirms the full pipeline before committing to the 8-variant sweep.

# %%
# !uv run python -m src.training.train \
    --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet \
    --arch hierarchical_transformer \
    --batch-size 8 --num-workers 2 \
    --max-epochs 2 --limit-batches 16 \
    --experiment-name smoke_test \
    --log-dir logs/architecture_ablation
# Out:
# 2026-04-26 19:54:15.104 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/s2t-tr-dev/src/training/train.py", line 47, in <module>
#     import pytorch_lightning as pl
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/__init__.py", line 25, in <module>
#     from lightning_fabric.utilities.seed import seed_everything  # noqa: E402
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/__init__.py", line 35, in <module>
#     from lightning_fabric.fabric import Fabric  # noqa: E402
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/fabric.py", line 39, in <module>
#     from lightning_fabric.accelerators.accelerator import Accelerator
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/accelerators/__init__.py", line 15, in <module>
#     from lightning_fabric.accelerators.accelerator import Accelerator
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/accelerators/accelerator.py", line 19, in <module>
#     from lightning_fabric.accelerators.registry import _AcceleratorRegistry
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/accelerators/registry.py", line 18, in <module>
#     from lightning_fabric.utilities.exceptions import MisconfigurationException
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/utilities/__init__.py", line 16, in <module>
#     from lightning_fabric.utilities.apply_func import move_data_to_device
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/utilities/apply_func.py", line 24, in <module>
#     from lightning_fabric.utilities.imports import _NUMPY_AVAILABLE
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_fabric/utilities/imports.py", line 41, in <module>
#     _TORCHMETRICS_GREATER_EQUAL_1_0_0 = compare_version("torchmetrics", operator.ge, "1.0.0")
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/lightning_utilities/core/imports.py", line 78, in compare_version
#     pkg = importlib.import_module(package)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/__init__.py", line 37, in <module>
#     from torchmetrics import functional  # noqa: E402
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/functional/__init__.py", line 14, in <module>
#     from torchmetrics.functional.audio._deprecated import _permutation_invariant_training as permutation_invariant_training
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/functional/audio/__init__.py", line 14, in <module>
#     from torchmetrics.functional.audio.pit import permutation_invariant_training, pit_permutate
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/functional/audio/pit.py", line 22, in <module>
#     from torchmetrics.utilities import rank_zero_warn
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/utilities/__init__.py", line 14, in <module>
#     from torchmetrics.utilities.checks import check_forward_full_state_property
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/utilities/checks.py", line 26, in <module>
#     from torchmetrics.metric import Metric
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/metric.py", line 43, in <module>
#     from torchmetrics.utilities.plot import _AX_TYPE, _PLOT_OUT_TYPE, plot_single_or_multi_val
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/torchmetrics/utilities/plot.py", line 27, in <module>
#     import matplotlib.axes
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/axes/__init__.py", line 2, in <module>
#     from ._axes import Axes
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py", line 33, in <module>
#     import matplotlib.tri as mtri
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/tri/__init__.py", line 10, in <module>
#     from ._tripcolor import tripcolor
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/tri/_tripcolor.py", line 9, in <module>
#     def tripcolor(ax, *args, alpha=1.0, norm=None, cmap=None, vmin=None,
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/_docstring.py", line 124, in __call__
#     obj.__doc__ = inspect.cleandoc(obj.__doc__) % self.params
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/_docstring.py", line 83, in __missing__
#     return self.setdefault(key, kwdoc(cls))
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/artist.py", line 1851, in kwdoc
#     'Properties:\n' + '\n'.join(ai.pprint_setters(leadingspace=4)))
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/artist.py", line 1612, in pprint_setters
#     accepts = self.get_valid_values(prop)
#   File "/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/matplotlib/artist.py", line 1494, in get_valid_values
#     match = re.search(fr"(?m)^ *\*?{param_name} : (.+)", docstring)
#   File "/usr/lib/python3.10/re.py", line 200, in search
#     return _compile(pattern, flags).search(string)
# KeyboardInterrupt

# %% [markdown]
# ## 4. Run the architecture ablation
#
# 8 trained variants × ~25 min each on L4 ≈ 3–4 h. The orchestrator writes one combined `ablation_results.json` after every variant, so the run is checkpoint-safe — restart and existing variants will retrain (no resume logic; the dataset and loss are identical so this is fine).
#
# > **A100 settings**: `--max-epochs 30` (converges faster), `batch_size 16` in the JSON.
# > **T4 settings**: keep epochs at 50 but set `batch_size 4` to avoid OOM.

# %%
# !uv run python -m src.experiments.run_ablation \
    --config configs/architecture_ablation.json \
    --output-dir reports/ablations/architecture_ami
# Out:
# 2026-04-26 19:54:21.285 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# 2026-04-26 19:54:21,329 [INFO] __main__: ============================================================
# 2026-04-26 19:54:21,329 [INFO] __main__: Variant: default
# 2026-04-26 19:54:21,329 [INFO] __main__: ============================================================
# 2026-04-26 19:54:21,329 [INFO] __main__: >>> train variant=default
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.train --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet --experiment-name default --log-dir reports/ablations/architecture_ami --arch hierarchical_transformer --train-ratio 0.8 --val-ratio 0.1 --max-seq-len 2000 --batch-size 8 --num-workers 4 --max-epochs 50 --learning-rate 0.0001 --primary-weight 1.0 --aux-ce-weight 0.0 --soft-ce-weight 0.5 --soft-ce-temperature 0.1 --seed 42
# 2026-04-26 19:54:21.422 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Seed set to 42
# 2026-04-26 19:54:27,781 [INFO] httpx: HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/parquet/parquet.py "HTTP/1.1 404 Not Found"
# 2026-04-26 19:54:27,810 [INFO] src.data.dataset: Loaded 12612 samples from data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet
# 2026-04-26 19:54:27,810 [INFO] __main__: Dataset splits: train=10089, val=1261, test=1262
# 2026-04-26 19:54:27,856 [INFO] __main__: === Model Parameter Counts ===
# 2026-04-26 19:54:27,856 [INFO] __main__:                  projection:     656128
# 2026-04-26 19:54:27,856 [INFO] __main__:                pos_encoding:          0
# 2026-04-26 19:54:27,856 [INFO] __main__:            model_embeddings:        768
# 2026-04-26 19:54:27,856 [INFO] __main__:                  cls_tokens:        768
# 2026-04-26 19:54:27,856 [INFO] __main__:              stage1_encoder:    1054208
# 2026-04-26 19:54:27,856 [INFO] __main__:             cross_attention:     791040
# 2026-04-26 19:54:27,856 [INFO] __main__:              stage2_encoder:     527104
# 2026-04-26 19:54:27,856 [INFO] __main__:                  classifier:      66563
# 2026-04-26 19:54:27,856 [INFO] __main__:                  global_cls:        256
# 2026-04-26 19:54:27,856 [INFO] __main__:                       total:    3096835
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 2026-04-26 19:54:27,890 [INFO] __main__: Starting training...
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ ASRModelSelector │  3.1 M │ train │     0 │
# └───┴───────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 3.1 M
# Non-trainable params: 0
# Total params: 3.1 M
# Total estimated model params size (MB): 12
# Modules in train mode: 64
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Epoch 0: 100% 1261/1261 [08:01<00:00,  2.62it/s, v_num=0, train/total_loss_step=0.909, train/selected_wer_step=0.295, train/selection_accuracy_step=0.500]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.98it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:42,  2.78it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.76it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.66it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.75it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.71it/s]
# Validation DataLoader 0:  89% 140/158 [00:51<00:06,  2.72it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# Validation DataLoader 0: 100% 158/158 [00:58<00:00,  2.70it/s]
# Epoch 0: 100% 1261/1261 [09:02<00:00,  2.32it/s, v_num=0, train/total_loss_step=0.909, train/selected_wer_step=0.295, train/selection_accuracy_step=0.500, val/total_loss=0.953, val/selected_wer=0.351, val/selection_accuracy=0.293, train/total_loss_epoch=1.010, train/selected_wer_epoch=0.426, train/selection_accuracy_epoch=0.378]Metric val/selected_wer improved. New best score: 0.351
# Epoch 1: 100% 1261/1261 [07:52<00:00,  2.67it/s, v_num=0, train/total_loss_step=0.980, train/selected_wer_step=0.403, train/selection_accuracy_step=0.250, val/total_loss=0.953, val/selected_wer=0.351, val/selection_accuracy=0.293, train/total_loss_epoch=1.010, train/selected_wer_epoch=0.426, train/selection_accuracy_epoch=0.378]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:44,  3.07it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:39,  2.96it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:32,  2.99it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.73it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.81it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.76it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.79it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.76it/s]
# Epoch 2: 100% 1261/1261 [08:00<00:00,  2.62it/s, v_num=0, train/total_loss_step=1.010, train/selected_wer_step=0.446, train/selection_accuracy_step=0.125, val/total_loss=0.924, val/selected_wer=0.351, val/selection_accuracy=0.451, train/total_loss_epoch=0.958, train/selected_wer_epoch=0.389, train/selection_accuracy_epoch=0.412]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:44,  3.08it/s]
# Validation DataLoader 0:  25% 40/158 [00:12<00:37,  3.16it/s]
# Validation DataLoader 0:  38% 60/158 [00:18<00:30,  3.22it/s]
# Validation DataLoader 0:  51% 80/158 [00:27<00:26,  2.92it/s]
# Validation DataLoader 0:  63% 100/158 [00:33<00:19,  2.96it/s]
# Validation DataLoader 0:  76% 120/158 [00:41<00:13,  2.89it/s]
# Validation DataLoader 0:  89% 140/158 [00:48<00:06,  2.90it/s]
# Validation DataLoader 0: 100% 158/158 [00:55<00:00,  2.86it/s]
# Epoch 2: 100% 1261/1261 [08:58<00:00,  2.34it/s, v_num=0, train/total_loss_step=1.010, train/selected_wer_step=0.446, train/selection_accuracy_step=0.125, val/total_loss=0.895, val/selected_wer=0.325, val/selection_accuracy=0.337, train/total_loss_epoch=0.928, train/selected_wer_epoch=0.368, train/selection_accuracy_epoch=0.429]Metric val/selected_wer improved by 0.027 >= min_delta = 0.0. New best score: 0.325
# Epoch 3: 100% 1261/1261 [07:59<00:00,  2.63it/s, v_num=0, train/total_loss_step=0.847, train/selected_wer_step=0.190, train/selection_accuracy_step=0.875, val/total_loss=0.895, val/selected_wer=0.325, val/selection_accuracy=0.337, train/total_loss_epoch=0.928, train/selected_wer_epoch=0.368, train/selection_accuracy_epoch=0.429]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:48,  2.82it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:42,  2.79it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.79it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.69it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.75it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:13,  2.72it/s]
# Validation DataLoader 0:  89% 140/158 [00:51<00:06,  2.74it/s]
# Validation DataLoader 0: 100% 158/158 [00:58<00:00,  2.71it/s]
# Epoch 4: 100% 1261/1261 [07:59<00:00,  2.63it/s, v_num=0, train/total_loss_step=1.150, train/selected_wer_step=0.656, train/selection_accuracy_step=0.500, val/total_loss=0.901, val/selected_wer=0.368, val/selection_accuracy=0.466, train/total_loss_epoch=0.893, train/selected_wer_epoch=0.358, train/selection_accuracy_epoch=0.451]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:44,  3.08it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:39,  3.02it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:32,  3.03it/s]
# Validation DataLoader 0:  51% 80/158 [00:27<00:27,  2.86it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:20,  2.88it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.82it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.82it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.78it/s]
# Epoch 5: 100% 1261/1261 [08:04<00:00,  2.61it/s, v_num=0, train/total_loss_step=0.950, train/selected_wer_step=0.237, train/selection_accuracy_step=0.125, val/total_loss=0.899, val/selected_wer=0.379, val/selection_accuracy=0.523, train/total_loss_epoch=0.866, train/selected_wer_epoch=0.320, train/selection_accuracy_epoch=0.468]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:45,  3.00it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:39,  2.96it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:32,  3.00it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.85it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:19,  2.92it/s]
# Validation DataLoader 0:  76% 120/158 [00:41<00:13,  2.86it/s]
# Validation DataLoader 0:  89% 140/158 [00:48<00:06,  2.91it/s]
# Validation DataLoader 0: 100% 158/158 [00:55<00:00,  2.87it/s]
# Epoch 6: 100% 1261/1261 [07:49<00:00,  2.68it/s, v_num=0, train/total_loss_step=0.685, train/selected_wer_step=0.188, train/selection_accuracy_step=0.500, val/total_loss=0.901, val/selected_wer=0.326, val/selection_accuracy=0.422, train/total_loss_epoch=0.853, train/selected_wer_epoch=0.334, train/selection_accuracy_epoch=0.491]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:48,  2.83it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:44,  2.66it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:34,  2.83it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.74it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.82it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.79it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.78it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.76it/s]
# Epoch 7: 100% 1261/1261 [08:03<00:00,  2.61it/s, v_num=0, train/total_loss_step=0.786, train/selected_wer_step=0.266, train/selection_accuracy_step=0.625, val/total_loss=0.903, val/selected_wer=0.328, val/selection_accuracy=0.489, train/total_loss_epoch=0.834, train/selected_wer_epoch=0.329, train/selection_accuracy_epoch=0.503]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:54,  2.55it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:40,  2.91it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.97it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.81it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:20,  2.88it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.83it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.85it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.81it/s]
# Epoch 8: 100% 1261/1261 [07:53<00:00,  2.66it/s, v_num=0, train/total_loss_step=0.696, train/selected_wer_step=0.205, train/selection_accuracy_step=0.500, val/total_loss=0.910, val/selected_wer=0.370, val/selection_accuracy=0.480, train/total_loss_epoch=0.811, train/selected_wer_epoch=0.293, train/selection_accuracy_epoch=0.517]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:52,  2.65it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:46,  2.56it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.78it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:29,  2.68it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.78it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.75it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.76it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.74it/s]
# Epoch 9: 100% 1261/1261 [07:58<00:00,  2.64it/s, v_num=0, train/total_loss_step=0.802, train/selected_wer_step=0.366, train/selection_accuracy_step=0.375, val/total_loss=0.909, val/selected_wer=0.377, val/selection_accuracy=0.405, train/total_loss_epoch=0.805, train/selected_wer_epoch=0.290, train/selection_accuracy_epoch=0.535]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:47,  2.90it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:40,  2.89it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:34,  2.86it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.75it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.83it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.79it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.79it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.77it/s]
# Epoch 10: 100% 1261/1261 [07:57<00:00,  2.64it/s, v_num=0, train/total_loss_step=0.844, train/selected_wer_step=0.414, train/selection_accuracy_step=0.750, val/total_loss=0.921, val/selected_wer=0.371, val/selection_accuracy=0.460, train/total_loss_epoch=0.780, train/selected_wer_epoch=0.284, train/selection_accuracy_epoch=0.544]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:44,  3.07it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:40,  2.91it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.92it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.80it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.85it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.81it/s]
# Validation DataLoader 0:  89% 140/158 [00:52<00:06,  2.68it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.77it/s]
# Epoch 11: 100% 1261/1261 [08:13<00:00,  2.55it/s, v_num=0, train/total_loss_step=0.617, train/selected_wer_step=0.294, train/selection_accuracy_step=0.750, val/total_loss=0.959, val/selected_wer=0.363, val/selection_accuracy=0.425, train/total_loss_epoch=0.763, train/selected_wer_epoch=0.271, train/selection_accuracy_epoch=0.560]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:45,  3.05it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:43,  2.74it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.92it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.79it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.75it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.74it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.78it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.76it/s]
# Epoch 12: 100% 1261/1261 [07:57<00:00,  2.64it/s, v_num=0, train/total_loss_step=0.716, train/selected_wer_step=0.237, train/selection_accuracy_step=0.625, val/total_loss=0.941, val/selected_wer=0.364, val/selection_accuracy=0.383, train/total_loss_epoch=0.749, train/selected_wer_epoch=0.267, train/selection_accuracy_epoch=0.568]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:52,  2.65it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:46,  2.56it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.78it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:29,  2.69it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.75it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.71it/s]
# Validation DataLoader 0:  89% 140/158 [00:51<00:06,  2.72it/s]
# Validation DataLoader 0: 100% 158/158 [00:58<00:00,  2.70it/s]
# Epoch 12: 100% 1261/1261 [08:58<00:00,  2.34it/s, v_num=0, train/total_loss_step=0.716, train/selected_wer_step=0.237, train/selection_accuracy_step=0.625, val/total_loss=0.929, val/selected_wer=0.367, val/selection_accuracy=0.500, train/total_loss_epoch=0.739, train/selected_wer_epoch=0.265, train/selection_accuracy_epoch=0.581]Monitored metric val/selected_wer did not improve in the last 10 records. Best score: 0.325. Signaling Trainer to stop.
# Epoch 12: 100% 1261/1261 [08:58<00:00,  2.34it/s, v_num=0, train/total_loss_step=0.716, train/selected_wer_step=0.237, train/selection_accuracy_step=0.625, val/total_loss=0.929, val/selected_wer=0.367, val/selection_accuracy=0.500, train/total_loss_epoch=0.739, train/selected_wer_epoch=0.265, train/selection_accuracy_epoch=0.581]
# 2026-04-26 21:51:16,857 [INFO] __main__: Running test evaluation...
# Restoring states from the checkpoint path at /content/s2t-tr-dev/reports/ablations/architecture_ami/default/checkpoints/best-epoch=02.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/s2t-tr-dev/reports/ablations/architecture_ami/default/checkpoints/best-epoch=02.ckpt
# Testing DataLoader 0:  89% 140/158 [00:49<00:06,  2.85it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Testing DataLoader 0: 100% 158/158 [00:55<00:00,  2.86it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/freq_hubert      │    0.03803486377000809    │
# │    test/freq_wav2vec2     │     0.825673520565033     │
# │     test/freq_whisper     │    0.13629159331321716    │
# │       test/hard_ce        │    1.0995296239852905     │
# │      test/oracle_wer      │     0.236915722489357     │
# │     test/primary_loss     │    0.4161234200000763     │
# │     test/selected_wer     │    0.32500138878822327    │
# │  test/selection_accuracy  │    0.33755943179130554    │
# │       test/soft_ce        │    0.9846332669258118     │
# │      test/total_loss      │     0.908440113067627     │
# │       test/wer_gap        │    0.08808574825525284    │
# └───────────────────────────┴───────────────────────────┘
# 2026-04-26 21:52:16,421 [INFO] __main__: Training complete. Logs saved to reports/ablations/architecture_ami/default
# 2026-04-26 21:52:18,017 [INFO] __main__: >>> evaluate variant=default
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.evaluate --checkpoint reports/ablations/architecture_ami/default/checkpoints/last.ckpt --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet --split test --save-json reports/ablations/architecture_ami/default/test.json --train-ratio 0.8 --val-ratio 0.1 --max-seq-len 2000 --batch-size 8 --num-workers 4 --seed 42
# 2026-04-26 21:52:18.117 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Seed set to 42
# 2026-04-26 21:52:23,782 [INFO] __main__: Loading checkpoint: reports/ablations/architecture_ami/default/checkpoints/last.ckpt
# 2026-04-26 21:52:25,227 [INFO] httpx: HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/parquet/parquet.py "HTTP/1.1 404 Not Found"
# 2026-04-26 21:52:25,256 [INFO] src.data.dataset: Loaded 12612 samples from data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet
# 2026-04-26 21:52:25,257 [INFO] __main__: Evaluating on split 'test' (1262 samples)
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utiliti
# es/data.py:79: Trying to infer the `batch_size` from an ambiguous collection.
# The batch size we found is 8. To avoid any miscalculations, use `self.log(...,
# batch_size=batch_size)`.
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utiliti
# es/data.py:79: Trying to infer the `batch_size` from an ambiguous collection.
# The batch size we found is 6. To avoid any miscalculations, use `self.log(...,
# batch_size=batch_size)`.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/freq_hubert      │    0.08954041451215744    │
# │    test/freq_wav2vec2     │     0.589540421962738     │
# │     test/freq_whisper     │    0.3209191858768463     │
# │       test/hard_ce        │     1.097004771232605     │
# │      test/oracle_wer      │     0.236915722489357     │
# │     test/primary_loss     │    0.38393253087997437    │
# │     test/selected_wer     │    0.31584519147872925    │
# │  test/selection_accuracy  │    0.5063391327857971     │
# │       test/soft_ce        │     1.030930757522583     │
# │      test/total_loss      │    0.8993982076644897     │
# │       test/wer_gap        │    0.0789295956492424     │
# └───────────────────────────┴───────────────────────────┘
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158/158 0:00:57 • 0:00:00 2.64it/s
# 2026-04-26 21:53:27,686 [INFO] __main__: === Results (test) ===
# 2026-04-26 21:53:27,686 [INFO] __main__:   primary_loss          : 0.3839
# 2026-04-26 21:53:27,686 [INFO] __main__:   hard_ce               : 1.0970
# 2026-04-26 21:53:27,686 [INFO] __main__:   soft_ce               : 1.0309
# 2026-04-26 21:53:27,686 [INFO] __main__:   total_loss            : 0.8994
# 2026-04-26 21:53:27,686 [INFO] __main__:   selected_wer          : 0.3158
# 2026-04-26 21:53:27,686 [INFO] __main__:   oracle_wer            : 0.2369
# 2026-04-26 21:53:27,686 [INFO] __main__:   wer_gap               : 0.0789
# 2026-04-26 21:53:27,687 [INFO] __main__:   selection_accuracy    : 0.5063
# 2026-04-26 21:53:27,687 [INFO] __main__:   freq_hubert           : 0.0895
# 2026-04-26 21:53:27,687 [INFO] __main__:   freq_whisper          : 0.3209
# 2026-04-26 21:53:27,687 [INFO] __main__:   freq_wav2vec2         : 0.5895
# 2026-04-26 21:53:27,687 [INFO] __main__: Saved results to reports/ablations/architecture_ami/default/test.json
# 2026-04-26 21:53:29,225 [INFO] __main__: ============================================================
# 2026-04-26 21:53:29,225 [INFO] __main__: Variant: no_bridge
# 2026-04-26 21:53:29,225 [INFO] __main__: ============================================================
# 2026-04-26 21:53:29,225 [INFO] __main__: >>> train variant=no_bridge
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.train --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet --experiment-name no_bridge --log-dir reports/ablations/architecture_ami --arch hierarchical_transformer --train-ratio 0.8 --val-ratio 0.1 --max-seq-len 2000 --batch-size 8 --num-workers 4 --max-epochs 50 --learning-rate 0.0001 --primary-weight 1.0 --aux-ce-weight 0.0 --soft-ce-weight 0.5 --soft-ce-temperature 0.1 --seed 42 --no-cross-attention
# 2026-04-26 21:53:29.324 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Seed set to 42
# 2026-04-26 21:53:35,698 [INFO] httpx: HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/parquet/parquet.py "HTTP/1.1 404 Not Found"
# 2026-04-26 21:53:35,728 [INFO] src.data.dataset: Loaded 12612 samples from data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet
# 2026-04-26 21:53:35,728 [INFO] __main__: Dataset splits: train=10089, val=1261, test=1262
# 2026-04-26 21:53:35,761 [INFO] __main__: === Model Parameter Counts ===
# 2026-04-26 21:53:35,761 [INFO] __main__:                  projection:     656128
# 2026-04-26 21:53:35,761 [INFO] __main__:                pos_encoding:          0
# 2026-04-26 21:53:35,761 [INFO] __main__:            model_embeddings:        768
# 2026-04-26 21:53:35,762 [INFO] __main__:                  cls_tokens:        768
# 2026-04-26 21:53:35,762 [INFO] __main__:              stage1_encoder:    1054208
# 2026-04-26 21:53:35,762 [INFO] __main__:              stage2_encoder:     527104
# 2026-04-26 21:53:35,762 [INFO] __main__:                  classifier:      66563
# 2026-04-26 21:53:35,762 [INFO] __main__:                  global_cls:        256
# 2026-04-26 21:53:35,762 [INFO] __main__:                       total:    2305795
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 2026-04-26 21:53:35,796 [INFO] __main__: Starting training...
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ ASRModelSelector │  2.3 M │ train │     0 │
# └───┴───────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 2.3 M
# Non-trainable params: 0
# Total params: 2.3 M
# Total estimated model params size (MB): 9
# Modules in train mode: 48
# Modules in eval mode: 0
# Total FLOPs: 0
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 8. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Epoch 0: 100% 1261/1261 [08:20<00:00,  2.52it/s, v_num=0, train/total_loss_step=0.636, train/selected_wer_step=0.117, train/selection_accuracy_step=0.250]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:47,  2.92it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:41,  2.86it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.89it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.73it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:20,  2.77it/s]
# Validation DataLoader 0:  76% 120/158 [00:45<00:14,  2.66it/s]
# Validation DataLoader 0:  89% 140/158 [00:52<00:06,  2.67it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 5. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.64it/s]
# Epoch 0: 100% 1261/1261 [09:22<00:00,  2.24it/s, v_num=0, train/total_loss_step=0.636, train/selected_wer_step=0.117, train/selection_accuracy_step=0.250, val/total_loss=0.930, val/selected_wer=0.355, val/selection_accuracy=0.240, train/total_loss_epoch=1.020, train/selected_wer_epoch=0.417, train/selection_accuracy_epoch=0.375]Metric val/selected_wer improved. New best score: 0.355
# Epoch 1: 100% 1261/1261 [08:15<00:00,  2.55it/s, v_num=0, train/total_loss_step=1.340, train/selected_wer_step=0.271, train/selection_accuracy_step=0.250, val/total_loss=0.930, val/selected_wer=0.355, val/selection_accuracy=0.240, train/total_loss_epoch=1.020, train/selected_wer_epoch=0.417, train/selection_accuracy_epoch=0.375]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:49,  2.80it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:41,  2.85it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.73it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:30,  2.59it/s]
# Validation DataLoader 0:  63% 100/158 [00:37<00:21,  2.66it/s]
# Validation DataLoader 0:  76% 120/158 [00:46<00:14,  2.57it/s]
# Validation DataLoader 0:  89% 140/158 [00:54<00:06,  2.58it/s]
# Validation DataLoader 0: 100% 158/158 [01:01<00:00,  2.56it/s]
# Epoch 1: 100% 1261/1261 [09:19<00:00,  2.25it/s, v_num=0, train/total_loss_step=1.340, train/selected_wer_step=0.271, train/selection_accuracy_step=0.250, val/total_loss=0.914, val/selected_wer=0.340, val/selection_accuracy=0.302, train/total_loss_epoch=0.956, train/selected_wer_epoch=0.407, train/selection_accuracy_epoch=0.397]Metric val/selected_wer improved by 0.014 >= min_delta = 0.0. New best score: 0.340
# Epoch 2: 100% 1261/1261 [08:19<00:00,  2.53it/s, v_num=0, train/total_loss_step=0.981, train/selected_wer_step=0.410, train/selection_accuracy_step=0.250, val/total_loss=0.914, val/selected_wer=0.340, val/selection_accuracy=0.302, train/total_loss_epoch=0.956, train/selected_wer_epoch=0.407, train/selection_accuracy_epoch=0.397]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.94it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:40,  2.92it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.93it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:28,  2.76it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.82it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.70it/s]
# Validation DataLoader 0:  89% 140/158 [00:51<00:06,  2.70it/s]
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.68it/s]
# Epoch 2: 100% 1261/1261 [09:20<00:00,  2.25it/s, v_num=0, train/total_loss_step=0.981, train/selected_wer_step=0.410, train/selection_accuracy_step=0.250, val/total_loss=0.898, val/selected_wer=0.335, val/selection_accuracy=0.330, train/total_loss_epoch=0.933, train/selected_wer_epoch=0.375, train/selection_accuracy_epoch=0.421]Metric val/selected_wer improved by 0.006 >= min_delta = 0.0. New best score: 0.335
# Epoch 3: 100% 1261/1261 [08:28<00:00,  2.48it/s, v_num=0, train/total_loss_step=0.637, train/selected_wer_step=0.161, train/selection_accuracy_step=0.500, val/total_loss=0.898, val/selected_wer=0.335, val/selection_accuracy=0.330, train/total_loss_epoch=0.933, train/selected_wer_epoch=0.375, train/selection_accuracy_epoch=0.421]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:49,  2.77it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:45,  2.62it/s]
# Validation DataLoader 0:  38% 60/158 [00:22<00:37,  2.62it/s]
# Validation DataLoader 0:  51% 80/158 [00:31<00:30,  2.54it/s]
# Validation DataLoader 0:  63% 100/158 [00:37<00:21,  2.64it/s]
# Validation DataLoader 0:  76% 120/158 [00:46<00:14,  2.60it/s]
# Validation DataLoader 0:  89% 140/158 [00:56<00:07,  2.49it/s]
# Validation DataLoader 0: 100% 158/158 [01:02<00:00,  2.53it/s]
# Epoch 4: 100% 1261/1261 [08:08<00:00,  2.58it/s, v_num=0, train/total_loss_step=1.010, train/selected_wer_step=0.393, train/selection_accuracy_step=0.500, val/total_loss=0.903, val/selected_wer=0.358, val/selection_accuracy=0.483, train/total_loss_epoch=0.905, train/selected_wer_epoch=0.361, train/selection_accuracy_epoch=0.446]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:08<00:57,  2.42it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:44,  2.68it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:34,  2.83it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:29,  2.69it/s]
# Validation DataLoader 0:  63% 100/158 [00:37<00:22,  2.64it/s]
# Validation DataLoader 0:  76% 120/158 [00:46<00:14,  2.58it/s]
# Validation DataLoader 0:  89% 140/158 [00:54<00:06,  2.59it/s]
# Validation DataLoader 0: 100% 158/158 [01:01<00:00,  2.57it/s]
# Epoch 5: 100% 1261/1261 [08:12<00:00,  2.56it/s, v_num=0, train/total_loss_step=0.844, train/selected_wer_step=0.249, train/selection_accuracy_step=0.625, val/total_loss=0.901, val/selected_wer=0.380, val/selection_accuracy=0.384, train/total_loss_epoch=0.880, train/selected_wer_epoch=0.327, train/selection_accuracy_epoch=0.463]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:49,  2.81it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:45,  2.58it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.73it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.62it/s]
# Validation DataLoader 0:  63% 100/158 [00:38<00:22,  2.58it/s]
# Validation DataLoader 0:  76% 120/158 [00:46<00:14,  2.58it/s]
# Validation DataLoader 0:  89% 140/158 [00:56<00:07,  2.47it/s]
# Validation DataLoader 0: 100% 158/158 [01:01<00:00,  2.57it/s]
# Epoch 6: 100% 1261/1261 [08:15<00:00,  2.55it/s, v_num=0, train/total_loss_step=0.810, train/selected_wer_step=0.250, train/selection_accuracy_step=0.375, val/total_loss=0.905, val/selected_wer=0.380, val/selection_accuracy=0.486, train/total_loss_epoch=0.851, train/selected_wer_epoch=0.307, train/selection_accuracy_epoch=0.487]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:50,  2.72it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:42,  2.76it/s]
# Validation DataLoader 0:  38% 60/158 [00:22<00:35,  2.72it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.62it/s]
# Validation DataLoader 0:  63% 100/158 [00:37<00:21,  2.70it/s]
# Validation DataLoader 0:  76% 120/158 [00:45<00:14,  2.67it/s]
# Validation DataLoader 0:  89% 140/158 [00:52<00:06,  2.67it/s]
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.64it/s]
# Epoch 7: 100% 1261/1261 [08:17<00:00,  2.53it/s, v_num=0, train/total_loss_step=0.514, train/selected_wer_step=0.120, train/selection_accuracy_step=0.250, val/total_loss=0.892, val/selected_wer=0.350, val/selection_accuracy=0.393, train/total_loss_epoch=0.849, train/selected_wer_epoch=0.335, train/selection_accuracy_epoch=0.503]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:47,  2.91it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:43,  2.69it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.74it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.62it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.71it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.67it/s]
# Validation DataLoader 0:  89% 140/158 [00:51<00:06,  2.70it/s]
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.67it/s]
# Epoch 8: 100% 1261/1261 [08:11<00:00,  2.57it/s, v_num=0, train/total_loss_step=0.858, train/selected_wer_step=0.133, train/selection_accuracy_step=0.375, val/total_loss=0.922, val/selected_wer=0.381, val/selection_accuracy=0.456, train/total_loss_epoch=0.824, train/selected_wer_epoch=0.292, train/selection_accuracy_epoch=0.515]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:49,  2.80it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:43,  2.72it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:34,  2.82it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:29,  2.68it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.75it/s]
# Validation DataLoader 0:  76% 120/158 [00:45<00:14,  2.65it/s]
# Validation DataLoader 0:  89% 140/158 [00:52<00:06,  2.65it/s]
# Validation DataLoader 0: 100% 158/158 [01:00<00:00,  2.63it/s]
# Epoch 9: 100% 1261/1261 [08:21<00:00,  2.52it/s, v_num=0, train/total_loss_step=0.926, train/selected_wer_step=0.356, train/selection_accuracy_step=0.375, val/total_loss=0.903, val/selected_wer=0.355, val/selection_accuracy=0.454, train/total_loss_epoch=0.802, train/selected_wer_epoch=0.286, train/selection_accuracy_epoch=0.529]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.96it/s]
# Validation DataLoader 0:  25% 40/158 [00:15<00:44,  2.64it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.78it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.65it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.73it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.68it/s]
# Validation DataLoader 0:  89% 140/158 [00:52<00:06,  2.67it/s]
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.64it/s]
# Epoch 10: 100% 1261/1261 [08:28<00:00,  2.48it/s, v_num=0, train/total_loss_step=1.060, train/selected_wer_step=0.437, train/selection_accuracy_step=0.750, val/total_loss=0.921, val/selected_wer=0.366, val/selection_accuracy=0.441, train/total_loss_epoch=0.796, train/selected_wer_epoch=0.292, train/selection_accuracy_epoch=0.544]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:51,  2.68it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:42,  2.80it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:34,  2.85it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.70it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:20,  2.77it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:13,  2.72it/s]
# Validation DataLoader 0:  89% 140/158 [00:54<00:06,  2.59it/s]
# Validation DataLoader 0: 100% 158/158 [01:00<00:00,  2.62it/s]
# Epoch 11: 100% 1261/1261 [08:16<00:00,  2.54it/s, v_num=0, train/total_loss_step=0.594, train/selected_wer_step=0.119, train/selection_accuracy_step=0.625, val/total_loss=0.935, val/selected_wer=0.353, val/selection_accuracy=0.407, train/total_loss_epoch=0.780, train/selected_wer_epoch=0.277, train/selection_accuracy_epoch=0.553]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.96it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:41,  2.87it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:35,  2.78it/s]
# Validation DataLoader 0:  51% 80/158 [00:30<00:29,  2.64it/s]
# Validation DataLoader 0:  63% 100/158 [00:37<00:21,  2.68it/s]
# Validation DataLoader 0:  76% 120/158 [00:46<00:14,  2.59it/s]
# Validation DataLoader 0:  89% 140/158 [00:53<00:06,  2.60it/s]
# Validation DataLoader 0: 100% 158/158 [01:01<00:00,  2.59it/s]
# Epoch 12: 100% 1261/1261 [08:17<00:00,  2.53it/s, v_num=0, train/total_loss_step=0.874, train/selected_wer_step=0.316, train/selection_accuracy_step=0.625, val/total_loss=0.947, val/selected_wer=0.387, val/selection_accuracy=0.406, train/total_loss_epoch=0.765, train/selected_wer_epoch=0.273, train/selection_accuracy_epoch=0.567]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.98it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:41,  2.82it/s]
# Validation DataLoader 0:  38% 60/158 [00:21<00:34,  2.85it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.70it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.76it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:14,  2.71it/s]
# Validation DataLoader 0:  89% 140/158 [00:54<00:06,  2.58it/s]
# Validation DataLoader 0: 100% 158/158 [01:00<00:00,  2.61it/s]
# Epoch 12: 100% 1261/1261 [09:20<00:00,  2.25it/s, v_num=0, train/total_loss_step=0.874, train/selected_wer_step=0.316, train/selection_accuracy_step=0.625, val/total_loss=0.962, val/selected_wer=0.387, val/selection_accuracy=0.489, train/total_loss_epoch=0.757, train/selected_wer_epoch=0.280, train/selection_accuracy_epoch=0.570]Monitored metric val/selected_wer did not improve in the last 10 records. Best score: 0.335. Signaling Trainer to stop.
# Epoch 12: 100% 1261/1261 [09:20<00:00,  2.25it/s, v_num=0, train/total_loss_step=0.874, train/selected_wer_step=0.316, train/selection_accuracy_step=0.625, val/total_loss=0.962, val/selected_wer=0.387, val/selection_accuracy=0.489, train/total_loss_epoch=0.757, train/selected_wer_epoch=0.280, train/selection_accuracy_epoch=0.570]
# 2026-04-26 23:55:12,357 [INFO] __main__: Running test evaluation...
# Restoring states from the checkpoint path at /content/s2t-tr-dev/reports/ablations/architecture_ami/no_bridge/checkpoints/best-epoch=02.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/s2t-tr-dev/reports/ablations/architecture_ami/no_bridge/checkpoints/best-epoch=02.ckpt
# Testing DataLoader 0:  89% 140/158 [00:52<00:06,  2.69it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Testing DataLoader 0: 100% 158/158 [00:58<00:00,  2.71it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/freq_hubert      │   0.003169572213664651    │
# │    test/freq_wav2vec2     │    0.7638669013977051     │
# │     test/freq_whisper     │    0.23296354711055756    │
# │       test/hard_ce        │    1.1509066820144653     │
# │      test/oracle_wer      │     0.236915722489357     │
# │     test/primary_loss     │    0.41580283641815186    │
# │     test/selected_wer     │    0.38421663641929626    │
# │  test/selection_accuracy  │    0.34389856457710266    │
# │       test/soft_ce        │    0.9815031290054321     │
# │      test/total_loss      │    0.9065542817115784     │
# │       test/wer_gap        │    0.1473010778427124     │
# └───────────────────────────┴───────────────────────────┘
# 2026-04-26 23:56:15,468 [INFO] __main__: Training complete. Logs saved to reports/ablations/architecture_ami/no_bridge
# 2026-04-26 23:56:17,076 [INFO] __main__: >>> evaluate variant=no_bridge
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.evaluate --checkpoint reports/ablations/architecture_ami/no_bridge/checkpoints/last.ckpt --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet --split test --save-json reports/ablations/architecture_ami/no_bridge/test.json --train-ratio 0.8 --val-ratio 0.1 --max-seq-len 2000 --batch-size 8 --num-workers 4 --seed 42
# 2026-04-26 23:56:17.170 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Seed set to 42
# 2026-04-26 23:56:22,933 [INFO] __main__: Loading checkpoint: reports/ablations/architecture_ami/no_bridge/checkpoints/last.ckpt
# 2026-04-26 23:56:24,217 [INFO] httpx: HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/parquet/parquet.py "HTTP/1.1 404 Not Found"
# 2026-04-26 23:56:24,244 [INFO] src.data.dataset: Loaded 12612 samples from data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet
# 2026-04-26 23:56:24,245 [INFO] __main__: Evaluating on split 'test' (1262 samples)
# ...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:47,  2.91it/s]
# Validation DataLoader 0:  25% 40/158 [00:12<00:38,  3.08it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:32,  3.03it/s]
# Validation DataLoader 0:  51% 80/158 [00:27<00:27,  2.87it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.82it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.80it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.85it/s]
# Validation DataLoader 0: 100% 158/158 [00:55<00:00,  2.83it/s]
# Epoch 8: 100% 1261/1261 [07:48<00:00,  2.69it/s, v_num=0, train/total_loss_step=0.905, train/selected_wer_step=0.324, train/selection_accuracy_step=0.500, val/total_loss=0.885, val/selected_wer=0.334, val/selection_accuracy=0.508, train/total_loss_epoch=0.854, train/selected_wer_epoch=0.319, train/selection_accuracy_epoch=0.498]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:53,  2.60it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:39,  2.97it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:32,  3.01it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.83it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:19,  2.92it/s]
# Validation DataLoader 0:  76% 120/158 [00:41<00:13,  2.86it/s]
# Validation DataLoader 0:  89% 140/158 [00:48<00:06,  2.90it/s]
# Validation DataLoader 0: 100% 158/158 [00:55<00:00,  2.85it/s]
# Epoch 9: 100% 1261/1261 [07:51<00:00,  2.67it/s, v_num=0, train/total_loss_step=0.916, train/selected_wer_step=0.433, train/selection_accuracy_step=0.500, val/total_loss=0.890, val/selected_wer=0.340, val/selection_accuracy=0.472, train/total_loss_epoch=0.850, train/selected_wer_epoch=0.326, train/selection_accuracy_epoch=0.506]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:45,  3.04it/s]
# Validation DataLoader 0:  25% 40/158 [00:12<00:37,  3.16it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:32,  3.01it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.85it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:19,  2.90it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.82it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.82it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.80it/s]
# Epoch 10: 100% 1261/1261 [07:55<00:00,  2.65it/s, v_num=0, train/total_loss_step=0.799, train/selected_wer_step=0.346, train/selection_accuracy_step=0.125, val/total_loss=0.903, val/selected_wer=0.342, val/selection_accuracy=0.428, train/total_loss_epoch=0.826, train/selected_wer_epoch=0.309, train/selection_accuracy_epoch=0.516]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:44,  3.12it/s]
# Validation DataLoader 0:  25% 40/158 [00:12<00:36,  3.19it/s]
# Validation DataLoader 0:  38% 60/158 [00:18<00:30,  3.19it/s]
# Validation DataLoader 0:  51% 80/158 [00:26<00:26,  2.96it/s]
# Validation DataLoader 0:  63% 100/158 [00:33<00:19,  2.98it/s]
# Validation DataLoader 0:  76% 120/158 [00:40<00:12,  2.93it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.78it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.81it/s]
# Epoch 11: 100% 1261/1261 [07:52<00:00,  2.67it/s, v_num=0, train/total_loss_step=0.533, train/selected_wer_step=0.0667, train/selection_accuracy_step=0.500, val/total_loss=0.898, val/selected_wer=0.339, val/selection_accuracy=0.386, train/total_loss_epoch=0.825, train/selected_wer_epoch=0.306, train/selection_accuracy_epoch=0.517]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:07<00:54,  2.52it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:41,  2.86it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.94it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.81it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:20,  2.77it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.76it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.77it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.75it/s]
# Epoch 12: 100% 1261/1261 [07:51<00:00,  2.67it/s, v_num=0, train/total_loss_step=0.655, train/selected_wer_step=0.108, train/selection_accuracy_step=0.250, val/total_loss=0.902, val/selected_wer=0.337, val/selection_accuracy=0.462, train/total_loss_epoch=0.804, train/selected_wer_epoch=0.298, train/selection_accuracy_epoch=0.525]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:47,  2.88it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:41,  2.83it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:34,  2.86it/s]
# Validation DataLoader 0:  51% 80/158 [00:29<00:28,  2.75it/s]
# Validation DataLoader 0:  63% 100/158 [00:36<00:21,  2.73it/s]
# Validation DataLoader 0:  76% 120/158 [00:44<00:13,  2.72it/s]
# Validation DataLoader 0:  89% 140/158 [00:53<00:06,  2.61it/s]
# Validation DataLoader 0: 100% 158/158 [00:59<00:00,  2.65it/s]
# Epoch 13: 100% 1261/1261 [07:51<00:00,  2.68it/s, v_num=0, train/total_loss_step=1.060, train/selected_wer_step=0.462, train/selection_accuracy_step=0.625, val/total_loss=0.903, val/selected_wer=0.351, val/selection_accuracy=0.517, train/total_loss_epoch=0.794, train/selected_wer_epoch=0.291, train/selection_accuracy_epoch=0.547]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:46,  2.96it/s]
# Validation DataLoader 0:  25% 40/158 [00:13<00:41,  2.88it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:33,  2.92it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.79it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.85it/s]
# Validation DataLoader 0:  76% 120/158 [00:42<00:13,  2.81it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.81it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.79it/s]
# Epoch 14: 100% 1261/1261 [07:41<00:00,  2.73it/s, v_num=0, train/total_loss_step=0.963, train/selected_wer_step=0.488, train/selection_accuracy_step=0.375, val/total_loss=0.915, val/selected_wer=0.342, val/selection_accuracy=0.367, train/total_loss_epoch=0.781, train/selected_wer_epoch=0.286, train/selection_accuracy_epoch=0.558]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:45,  3.06it/s]
# Validation DataLoader 0:  25% 40/158 [00:12<00:37,  3.11it/s]
# Validation DataLoader 0:  38% 60/158 [00:19<00:31,  3.10it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:27,  2.84it/s]
# Validation DataLoader 0:  63% 100/158 [00:34<00:19,  2.91it/s]
# Validation DataLoader 0:  76% 120/158 [00:41<00:13,  2.86it/s]
# Validation DataLoader 0:  89% 140/158 [00:49<00:06,  2.85it/s]
# Validation DataLoader 0: 100% 158/158 [00:56<00:00,  2.82it/s]
# Epoch 15: 100% 1261/1261 [07:51<00:00,  2.67it/s, v_num=0, train/total_loss_step=0.753, train/selected_wer_step=0.240, train/selection_accuracy_step=0.625, val/total_loss=0.925, val/selected_wer=0.332, val/selection_accuracy=0.482, train/total_loss_epoch=0.777, train/selected_wer_epoch=0.291, train/selection_accuracy_epoch=0.563]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/158 [00:00<?, ?it/s]
# Validation DataLoader 0:  13% 20/158 [00:06<00:48,  2.86it/s]
# Validation DataLoader 0:  25% 40/158 [00:14<00:43,  2.68it/s]
# Validation DataLoader 0:  38% 60/158 [00:20<00:34,  2.88it/s]
# Validation DataLoader 0:  51% 80/158 [00:28<00:28,  2.76it/s]
# Validation DataLoader 0:  63% 100/158 [00:35<00:20,  2.82it/s]
# Validation DataLoader 0:  76% 120/158 [00:43<00:13,  2.78it/s]
# Validation DataLoader 0:  89% 140/158 [00:50<00:06,  2.79it/s]
# Validation DataLoader 0: 100% 158/158 [00:57<00:00,  2.77it/s]
# Epoch 15: 100% 1261/1261 [08:50<00:00,  2.37it/s, v_num=0, train/total_loss_step=0.753, train/selected_wer_step=0.240, train/selection_accuracy_step=0.625, val/total_loss=0.945, val/selected_wer=0.365, val/selection_accuracy=0.531, train/total_loss_epoch=0.761, train/selected_wer_epoch=0.281, train/selection_accuracy_epoch=0.567]Monitored metric val/selected_wer did not improve in the last 10 records. Best score: 0.330. Signaling Trainer to stop.
# Epoch 15: 100% 1261/1261 [08:50<00:00,  2.37it/s, v_num=0, train/total_loss_step=0.753, train/selected_wer_step=0.240, train/selection_accuracy_step=0.625, val/total_loss=0.945, val/selected_wer=0.365, val/selection_accuracy=0.531, train/total_loss_epoch=0.761, train/selected_wer_epoch=0.281, train/selection_accuracy_epoch=0.567]
# 2026-04-27 14:59:09,580 [INFO] __main__: Running test evaluation...
# Restoring states from the checkpoint path at /content/s2t-tr-dev/reports/ablations/architecture_ami/d_model_512/checkpoints/best-epoch=05.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/s2t-tr-dev/reports/ablations/architecture_ami/d_model_512/checkpoints/best-epoch=05.ckpt
# Testing DataLoader 0:  89% 140/158 [00:48<00:06,  2.91it/s]/content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 6. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Testing DataLoader 0: 100% 158/158 [00:53<00:00,  2.94it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/freq_hubert      │    0.03645008057355881    │
# │    test/freq_wav2vec2     │    0.4659270942211151     │
# │     test/freq_whisper     │    0.4976228177547455     │
# │       test/hard_ce        │     1.097084641456604     │
# │      test/oracle_wer      │     0.236915722489357     │
# │     test/primary_loss     │     0.437112957239151     │
# │     test/selected_wer     │    0.44465354084968567    │
# │  test/selection_accuracy  │    0.4960380494594574     │
# │       test/soft_ce        │    0.9881058931350708     │
# │      test/total_loss      │    0.9311658143997192     │
# │       test/wer_gap        │    0.20773784816265106    │
# └───────────────────────────┴───────────────────────────┘
# 2026-04-27 15:00:07,900 [INFO] __main__: Training complete. Logs saved to reports/ablations/architecture_ami/d_model_512
# 2026-04-27 15:00:09,540 [INFO] __main__: >>> evaluate variant=d_model_512
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.evaluate --checkpoint reports/ablations/architecture_ami/d_model_512/checkpoints/last.ckpt --parquet-path data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet --split test --save-json reports/ablations/architecture_ami/d_model_512/test.json --train-ratio 0.8 --val-ratio 0.1 --max-seq-len 2000 --batch-size 8 --num-workers 4 --seed 42
# 2026-04-27 15:00:09.634 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# Seed set to 42
# 2026-04-27 15:00:15,297 [INFO] __main__: Loading checkpoint: reports/ablations/architecture_ami/d_model_512/checkpoints/last.ckpt
# 2026-04-27 15:00:16,771 [INFO] httpx: HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/parquet/parquet.py "HTTP/1.1 404 Not Found"
# 2026-04-27 15:00:16,797 [INFO] src.data.dataset: Loaded 12612 samples from data/processed/edinburghcstr_ami/combined_features-w2v2-large.parquet
# 2026-04-27 15:00:16,798 [INFO] __main__: Evaluating on split 'test' (1262 samples)
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utiliti
# es/data.py:79: Trying to infer the `batch_size` from an ambiguous collection.
# The batch size we found is 8. To avoid any miscalculations, use `self.log(...,
# batch_size=batch_size)`.
# /content/s2t-tr-dev/.venv/lib/python3.10/site-packages/pytorch_lightning/utiliti
# es/data.py:79: Trying to infer the `batch_size` from an ambiguous collection.
# The batch size we found is 6. To avoid any miscalculations, use `self.log(...,
# batch_size=batch_size)`.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/freq_hubert      │    0.07131537050008774    │
# │    test/freq_wav2vec2     │    0.4722662568092346     │
# │     test/freq_whisper     │    0.45641839504241943    │
# │       test/hard_ce        │    1.1843962669372559     │
# │      test/oracle_wer      │     0.236915722489357     │
# │     test/primary_loss     │    0.4174961745738983     │
# │     test/selected_wer     │    0.42213910818099976    │
# │  test/selection_accuracy  │    0.49524563550949097    │
# │       test/soft_ce        │    1.0950101613998413     │
# │      test/total_loss      │     0.965001106262207     │
# │       test/wer_gap        │    0.18522343039512634    │
# └───────────────────────────┴───────────────────────────┘
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158/158 0:00:53 • 0:00:00 2.94it/s
# 2026-04-27 15:01:14,815 [INFO] __main__: === Results (test) ===
# 2026-04-27 15:01:14,815 [INFO] __main__:   primary_loss          : 0.4175
# 2026-04-27 15:01:14,815 [INFO] __main__:   hard_ce               : 1.1844
# 2026-04-27 15:01:14,815 [INFO] __main__:   soft_ce               : 1.0950
# 2026-04-27 15:01:14,815 [INFO] __main__:   total_loss            : 0.9650
# 2026-04-27 15:01:14,815 [INFO] __main__:   selected_wer          : 0.4221
# 2026-04-27 15:01:14,815 [INFO] __main__:   oracle_wer            : 0.2369
# 2026-04-27 15:01:14,815 [INFO] __main__:   wer_gap               : 0.1852
# 2026-04-27 15:01:14,815 [INFO] __main__:   selection_accuracy    : 0.4952
# 2026-04-27 15:01:14,815 [INFO] __main__:   freq_hubert           : 0.0713
# 2026-04-27 15:01:14,816 [INFO] __main__:   freq_whisper          : 0.4564
# 2026-04-27 15:01:14,816 [INFO] __main__:   freq_wav2vec2         : 0.4723
# 2026-04-27 15:01:14,816 [INFO] __main__: Saved results to reports/ablations/architecture_ami/d_model_512/test.json
# 2026-04-27 15:01:16,274 [INFO] __main__: Ablation complete. Aggregated results at reports/ablations/architecture_ami/ablation_results.json

# %% [markdown]
# ## 5. Render the table
#
# Prints one row per variant (test selected_wer, oracle_wer, gap, selection_accuracy). This is the data backing the ablation table in the manuscript.

# %%
import json
from pathlib import Path

results = json.loads(Path('reports/ablations/architecture_ami/ablation_results.json').read_text())
rows = []
for name, entry in results['variants'].items():
    t = entry['test']
    rows.append((name, t['selected_wer'], t['oracle_wer'], t['wer_gap'], t['selection_accuracy']))

print(f"{'variant':<22} {'sel_wer':>8} {'oracle':>8} {'gap':>8} {'sel_acc':>8}")
print('-' * 64)
for r in rows:
    print(f"{r[0]:<22} {r[1]:>8.4f} {r[2]:>8.4f} {r[3]:>8.4f} {r[4]:>8.4f}")
# Out:
# variant                 sel_wer   oracle      gap  sel_acc
# ----------------------------------------------------------------
# default                  0.3158   0.2369   0.0789   0.5063
# no_bridge                0.4293   0.2369   0.1924   0.4081
# separate_stage1          0.3405   0.2369   0.1036   0.4921
# stage1_layers_1          0.4528   0.2369   0.2158   0.4477
# stage1_layers_4          0.3335   0.2369   0.0966   0.4002
# stage2_layers_2          0.3923   0.2369   0.1554   0.4802
# d_model_128              0.3277   0.2369   0.0908   0.4635
# d_model_512              0.4221   0.2369   0.1852   0.4952

# %% [markdown]
# ## 6. Backup logs to Drive

# %%
# !cp -r reports/ablations/architecture_ami /content/drive/MyDrive/s2t-tr-dev/ablations/architecture_ami_$(date +%Y%m%d_%H%M)
# Out:
# cp: cannot create directory '/content/drive/MyDrive/s2t-tr-dev/ablations/architecture_ami_20260427_1501': No such file or directory

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# ## Run the Architecture Ablation
#
# We use `main_results` to orchestrate training all architecture variants defined in `ablation_architecture.yaml`.
# This will automatically run training-free baselines (if applicable) and train all variants defined in the config.

# %%
# !uv run python -m src.experiments.main_results experiments=ablation_architecture

# %% [markdown]
# ## Pull Results from W&B
#
# This script queries the W&B API for runs matching this experiment group and prints a paper-ready markdown table.

# %%
# Ensure WANDB_API_KEY and WANDB_ENTITY are set in your Colab Secrets or environment
# !uv run python -m src.scripts.pull_wandb \
    --api-key $WANDB_API_KEY \
    --entity $WANDB_ENTITY \
    --group ablation_architecture
